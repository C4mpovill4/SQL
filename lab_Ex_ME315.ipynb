# %%
# !pip install pymysql pandas sqlalchemy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 1.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
user = "@@@@@"
password = "@@@@@@"
host = "@@@@@@@"
database = "@@@@"

# %%
conn = create_engine(f"mysql+pymysql://{user}:{password}@{host}/{database}")

# %%
conn = create_engine(f"mysql+pymysql://aluno:@@@@@@@@@@@@@@@@@@@")

# %%
conn
# Out:
# Engine(mysql+pymysql://%28%27aluno%27%2C%29:***@('107.180.0.110',)/me315)

# %%
pd.read_sql("""
    SELECT * FROM VaiCorinthians
    LIMIT 5
    """, conn)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
pd.read_sql(
    """
     SELECT Species, AVG(`Sepal.Length`) AS media
     FROM VaiCorinthians
     GROUP BY Species
""", conn)
# Out:
#       Species  media
# 0      setosa  5.006
# 1  versicolor  5.936
# 2   virginica  6.588

# %%
pd.read_sql("""
     SELECT Species,
           MAX(`Sepal.Length`),
           MAX(`Sepal.Width`),
           MAX(`Petal.Length`),
           MAX(`Petal.Width`)
     FROM VaiCorinthians
     GROUP BY Species
     """,
     conn)
# Out:
#       Species  MAX(`Sepal.Length`)  MAX(`Sepal.Width`)  MAX(`Petal.Length`)  \
# 0      setosa                  5.8                 4.4                  1.9
# 1  versicolor                  7.0                 3.4                  5.1
# 2   virginica                  7.9                 3.8                  6.9
#
#    MAX(`Petal.Width`)
# 0                 0.6
# 1                 1.8
# 2                 2.5
